# %%
from retinaface import RetinaFace
import matplotlib.pyplot as plt
import cv2

# %%
x=cv2.imread("itest.jpg") #thisis in bgr

# %%
plt.imshow(x)

# %%
faces=RetinaFace.detect_faces(x)

# %%
faces
# Out:
# {'face_1': {'score': 0.9998012185096741,
#   'facial_area': [2167, 104, 2838, 994],
#   'landmarks': {'right_eye': [2543.0977, 493.74945],
#    'left_eye': [2765.6548, 545.9212],
#    'nose': [2685.4956, 711.84485],
#    'mouth_right': [2422.1355, 753.4876],
#    'mouth_left': [2624.9, 803.7621]}},
#  'face_2': {'score': 0.9995743632316589,
#   'facial_area': [3010, 604, 3702, 1551],
#   'landmarks': {'right_eye': [3069.2598, 1030.9133],
#    'left_eye': [3305.8784, 985.99774],
#    'nose': [3123.8826, 1219.8158],
#    'mouth_right': [3181.859, 1321.3219],
#    'mouth_left': [3413.6692, 1282.2755]}}}

# %%
resp=RetinaFace.extract_faces(x)

# %%
for face in resp:
    plt.imshow(face)
    plt.show()
